# %% [markdown]
# cojo output

# %% [markdown]
# chr1

# %% [markdown]
# icog-bioai@dl:/mnt/hdd_2/rediet/hypothesis-generation-demo/data/susie/gcta/gcta-1.94.3-linux-kernel-3-x86_64$ gcta64 --bfile ../../ALL_chr/plink_b_files/chr1_eur_filtered --chr 1  --cojo-file ../../reformated_data_for_cojo/cojo_extracted_file.csv  --cojo-slct --out ../../cojo/chr1
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.94.1 Linux
# * Built at Dec 16 2024 16:35:13, by GCC 8.3
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 03:53:07 PST on Mon Feb 24 2025.
# Hostname: dl
#
# Accepted options:
# --bfile ../../ALL_chr/plink_b_files/chr1_eur_filtered
# --chr 1
# --cojo-file ../../reformated_data_for_cojo/cojo_extracted_file.csv
# --cojo-slct
# --out ../../cojo/chr1
#
#
# Reading PLINK FAM file from [../../ALL_chr/plink_b_files/chr1_eur_filtered.fam].
# 2504 individuals to be included from [../../ALL_chr/plink_b_files/chr1_eur_filtered.fam].
# Reading PLINK BIM file from [../../ALL_chr/plink_b_files/chr1_eur_filtered.bim].
# 1834 SNPs to be included from [../../ALL_chr/plink_b_files/chr1_eur_filtered.bim].
# 1834 SNPs on chromosome 1 are included in the analysis.
# Reading PLINK BED file from [../../ALL_chr/plink_b_files/chr1_eur_filtered.bed] in SNP-major format ...
# Genotype data for 2504 individuals and 1834 SNPs to be included from [../../ALL_chr/plink_b_files/chr1_eur_filtered.bed].
#
# Reading GWAS summary-level statistics from [../../reformated_data_for_cojo/cojo_extracted_file.csv] ...
# GWAS summary statistics of 49937 SNPs read from [../../reformated_data_for_cojo/cojo_extracted_file.csv].
# Phenotypic variance estimated from summary statistics of all 49937 SNPs: 22.4081 (variance of logit for case-control studies).
# Matching the GWAS meta-analysis results to the genotype data ...
# Calculating allele frequencies ...
# 595 SNP(s) have large difference of allele frequency between the GWAS summary data and the reference sample. These SNPs have been saved in [../../cojo/chr1/chr1.freq.badsnps].
# 1239 SNPs are matched to the genotype data.
# Calculating the variance of SNP genotypes ...
#
# Performing stepwise model selection on 1239 SNPs to select association signals ... (p cutoff = 5e-08; collinearity cutoff = 0.9)
# (Assuming complete linkage equilibrium between SNPs which are more than 10Mb away from each other)
# 5 associated SNPs have been selected.
# 10 associated SNPs have been selected.
# 15 associated SNPs have been selected.
# Finally, 17 associated SNPs are selected.
# Performing joint analysis on all the 17 selected signals ...
# Saving the 17 independent signals to [../../cojo/chr1/chr1.jma.cojo] ...
# Saving the LD structure of 17 independent signals to [../../cojo/chr1/chr1.ldr.cojo] ...
# Saving the conditional analysis results of 1222 remaining SNPs to [../../cojo/chr1/chr1.cma.cojo] ...
# (0 SNPs eliminated by backward selection and 0 SNPs filtered by collinearity test are not included in the output)
#
# Analysis finished at 03:53:08 PST on Mon Feb 24 2025
# Overall computational time: 0.75 sec.

# %% [markdown]
# chr2

# %% [markdown]
# icog-bioai@dl:/mnt/hdd_2/rediet/hypothesis-generation-demo/data/susie/gcta/gcta-1.94.3-linux-kernel-3-x86_64$ gcta64 --bfile ../../ALL_chr/plink_b_files/chr2_eur_filtered --chr 2  --cojo-file ../../reformated_data_for_cojo/cojo_extracted_file.csv
# --cojo-slct --out ../../cojo/chr2/chr2
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.94.1 Linux
# * Built at Dec 16 2024 16:35:13, by GCC 8.3
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 05:30:17 PST on Mon Feb 24 2025.
# Hostname: dl
#
# Accepted options:
# --bfile ../../ALL_chr/plink_b_files/chr2_eur_filtered
# --chr 2
# --cojo-file ../../reformated_data_for_cojo/cojo_extracted_file.csv
# --cojo-slct
# --out ../../cojo/chr2/chr2
#
#
# Reading PLINK FAM file from [../../ALL_chr/plink_b_files/chr2_eur_filtered.fam].
# 2504 individuals to be included from [../../ALL_chr/plink_b_files/chr2_eur_filtered.fam].
# Reading PLINK BIM file from [../../ALL_chr/plink_b_files/chr2_eur_filtered.bim].
# 4558 SNPs to be included from [../../ALL_chr/plink_b_files/chr2_eur_filtered.bim].
# 4558 SNPs on chromosome 2 are included in the analysis.
# Reading PLINK BED file from [../../ALL_chr/plink_b_files/chr2_eur_filtered.bed] in SNP-major format ...
# Genotype data for 2504 individuals and 4558 SNPs to be included from [../../ALL_chr/plink_b_files/chr2_eur_filtered.bed].
#
# Reading GWAS summary-level statistics from [../../reformated_data_for_cojo/cojo_extracted_file.csv] ...
# GWAS summary statistics of 49937 SNPs read from [../../reformated_data_for_cojo/cojo_extracted_file.csv].
# Phenotypic variance estimated from summary statistics of all 49937 SNPs: 22.4081 (variance of logit for case-control studies).
# Matching the GWAS meta-analysis results to the genotype data ...
# Calculating allele frequencies ...
# Warning: can't match the reference alleles of 1 SNPs to those in the genotype data. These SNPs have been saved in [../../cojo/chr2/chr2.badsnps].
# 875 SNP(s) have large difference of allele frequency between the GWAS summary data and the reference sample. These SNPs have been saved in [../../cojo/chr2/chr2.freq.badsnps].
# 3682 SNPs are matched to the genotype data.
# Calculating the variance of SNP genotypes ...
#
# Performing stepwise model selection on 3682 SNPs to select association signals ... (p cutoff = 5e-08; collinearity cutoff = 0.9)
# (Assuming complete linkage equilibrium between SNPs which are more than 10Mb away from each other)
# 5 associated SNPs have been selected.
# 10 associated SNPs have been selected.
# 15 associated SNPs have been selected.
# 20 associated SNPs have been selected.
# 25 associated SNPs have been selected.
# 30 associated SNPs have been selected.
# 35 associated SNPs have been selected.
# 40 associated SNPs have been selected.
# 45 associated SNPs have been selected.
# Finally, 49 associated SNPs are selected.
# Performing joint analysis on all the 49 selected signals ...
# Saving the 49 independent signals to [../../cojo/chr2/chr2.jma.cojo] ...
# Saving the LD structure of 49 independent signals to [../../cojo/chr2/chr2.ldr.cojo] ...
# Saving the conditional analysis results of 3633 remaining SNPs to [../../cojo/chr2/chr2.cma.cojo] ...
# (0 SNPs eliminated by backward selection and 0 SNPs filtered by collinearity test are not included in the output)
#
# Analysis finished at 05:30:21 PST on Mon Feb 24 2025
# Overall computational time: 3.52 sec.

# %% [markdown]
# chr3

# %% [markdown]
# icog-bioai@dl:/mnt/hdd_2/rediet/hypothesis-generation-demo/data/susie/gcta/gcta-1.94.3-linux-kernel-3-x86_64$ gcta64 --bfile ../../ALL_chr/plink_b_files/chr3_eur_filtered --chr 3  --cojo-file ../../reformated_data_for_cojo/cojo_extracted_file.csv  --cojo-slct --out ../../cojo/chr3/chr3
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.94.1 Linux
# * Built at Dec 16 2024 16:35:13, by GCC 8.3
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 05:35:04 PST on Mon Feb 24 2025.
# Hostname: dl
#
# Accepted options:
# --bfile ../../ALL_chr/plink_b_files/chr3_eur_filtered
# --chr 3
# --cojo-file ../../reformated_data_for_cojo/cojo_extracted_file.csv
# --cojo-slct
# --out ../../cojo/chr3/chr3
#
#
# Reading PLINK FAM file from [../../ALL_chr/plink_b_files/chr3_eur_filtered.fam].
# 2504 individuals to be included from [../../ALL_chr/plink_b_files/chr3_eur_filtered.fam].
# Reading PLINK BIM file from [../../ALL_chr/plink_b_files/chr3_eur_filtered.bim].
# 5979 SNPs to be included from [../../ALL_chr/plink_b_files/chr3_eur_filtered.bim].
# 5979 SNPs on chromosome 3 are included in the analysis.
# Reading PLINK BED file from [../../ALL_chr/plink_b_files/chr3_eur_filtered.bed] in SNP-major format ...
# Genotype data for 2504 individuals and 5979 SNPs to be included from [../../ALL_chr/plink_b_files/chr3_eur_filtered.bed].
#
# Reading GWAS summary-level statistics from [../../reformated_data_for_cojo/cojo_extracted_file.csv] ...
# GWAS summary statistics of 49937 SNPs read from [../../reformated_data_for_cojo/cojo_extracted_file.csv].
# Phenotypic variance estimated from summary statistics of all 49937 SNPs: 22.4081 (variance of logit for case-control studies).
# Matching the GWAS meta-analysis results to the genotype data ...
# Calculating allele frequencies ...
# Warning: can't match the reference alleles of 1 SNPs to those in the genotype data. These SNPs have been saved in [../../cojo/chr3/chr3.badsnps].
# 859 SNP(s) have large difference of allele frequency between the GWAS summary data and the reference sample. These SNPs have been saved in [../../cojo/chr3/chr3.freq.badsnps].
# 5119 SNPs are matched to the genotype data.
# Calculating the variance of SNP genotypes ...
#
# Performing stepwise model selection on 5119 SNPs to select association signals ... (p cutoff = 5e-08; collinearity cutoff = 0.9)
# (Assuming complete linkage equilibrium between SNPs which are more than 10Mb away from each other)
# 5 associated SNPs have been selected.
# 10 associated SNPs have been selected.
# 15 associated SNPs have been selected.
# 20 associated SNPs have been selected.
# 25 associated SNPs have been selected.
# 30 associated SNPs have been selected.
# 35 associated SNPs have been selected.
# 40 associated SNPs have been selected.
# 45 associated SNPs have been selected.
# 50 associated SNPs have been selected.
# Finally, 50 associated SNPs are selected.
# Performing joint analysis on all the 50 selected signals ...
# Saving the 50 independent signals to [../../cojo/chr3/chr3.jma.cojo] ...
# Saving the LD structure of 50 independent signals to [../../cojo/chr3/chr3.ldr.cojo] ...
# Saving the conditional analysis results of 5068 remaining SNPs to [../../cojo/chr3/chr3.cma.cojo] ...
# (1 SNPs eliminated by backward selection and 0 SNPs filtered by collinearity test are not included in the output)
#
# Analysis finished at 05:35:09 PST on Mon Feb 24 2025
# Overall computational time: 5.12 sec.

# %% [markdown]
# chr4

# %% [markdown]
# icog-bioai@dl:/mnt/hdd_2/rediet/hypothesis-generation-demo/data/susie/gcta/gcta-1.94.3-linux-kernel-3-x86_64$ gcta64 --bfile ../../ALL_chr/plink_b_files/chr4_eur_filtered --chr 4  --cojo-file ../../reformated_data_for_cojo/cojo_extracted_file.csv  --cojo-slct --out ../../cojo/chr4/chr4
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.94.1 Linux
# * Built at Dec 16 2024 16:35:13, by GCC 8.3
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 05:40:35 PST on Mon Feb 24 2025.
# Hostname: dl
#
# Accepted options:
# --bfile ../../ALL_chr/plink_b_files/chr4_eur_filtered
# --chr 4
# --cojo-file ../../reformated_data_for_cojo/cojo_extracted_file.csv
# --cojo-slct
# --out ../../cojo/chr4/chr4
#
#
# Reading PLINK FAM file from [../../ALL_chr/plink_b_files/chr4_eur_filtered.fam].
# 2504 individuals to be included from [../../ALL_chr/plink_b_files/chr4_eur_filtered.fam].
# Reading PLINK BIM file from [../../ALL_chr/plink_b_files/chr4_eur_filtered.bim].
# 1982 SNPs to be included from [../../ALL_chr/plink_b_files/chr4_eur_filtered.bim].
# 1982 SNPs on chromosome 4 are included in the analysis.
# Reading PLINK BED file from [../../ALL_chr/plink_b_files/chr4_eur_filtered.bed] in SNP-major format ...
# Genotype data for 2504 individuals and 1982 SNPs to be included from [../../ALL_chr/plink_b_files/chr4_eur_filtered.bed].
#
# Reading GWAS summary-level statistics from [../../reformated_data_for_cojo/cojo_extracted_file.csv] ...
# GWAS summary statistics of 49937 SNPs read from [../../reformated_data_for_cojo/cojo_extracted_file.csv].
# Phenotypic variance estimated from summary statistics of all 49937 SNPs: 22.4081 (variance of logit for case-control studies).
# Matching the GWAS meta-analysis results to the genotype data ...
# Calculating allele frequencies ...
# 329 SNP(s) have large difference of allele frequency between the GWAS summary data and the reference sample. These SNPs have been saved in [../../cojo/chr4/chr4.freq.badsnps].
# 1653 SNPs are matched to the genotype data.
# Calculating the variance of SNP genotypes ...
#
# Performing stepwise model selection on 1653 SNPs to select association signals ... (p cutoff = 5e-08; collinearity cutoff = 0.9)
# (Assuming complete linkage equilibrium between SNPs which are more than 10Mb away from each other)
# 5 associated SNPs have been selected.
# 10 associated SNPs have been selected.
# 15 associated SNPs have been selected.
# 20 associated SNPs have been selected.
# 25 associated SNPs have been selected.
# Finally, 26 associated SNPs are selected.
# Performing joint analysis on all the 26 selected signals ...
# Saving the 26 independent signals to [../../cojo/chr4/chr4.jma.cojo] ...
# Saving the LD structure of 26 independent signals to [../../cojo/chr4/chr4.ldr.cojo] ...
# Saving the conditional analysis results of 1627 remaining SNPs to [../../cojo/chr4/chr4.cma.cojo] ...
# (0 SNPs eliminated by backward selection and 0 SNPs filtered by collinearity test are not included in the output)
#
# Analysis finished at 05:40:36 PST on Mon Feb 24 2025
# Overall computational time: 0.98 sec.

# %% [markdown]
# chr 5

# %% [markdown]
# icog-bioai@dl:/mnt/hdd_2/rediet/hypothesis-generation-demo/data/susie/gcta/gcta-1.94.3-linux-kernel-3-x86_64$ gcta64 --bfile ../../ALL_chr/plink_b_files/chr5_eur_filtered --chr 5  --cojo-file ../../reformated_data_for_cojo/cojo_extracted_file.csv  --cojo-slct --out ../../cojo/chr5/chr5
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.94.1 Linux
# * Built at Dec 16 2024 16:35:13, by GCC 8.3
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 05:41:31 PST on Mon Feb 24 2025.
# Hostname: dl
#
# Accepted options:
# --bfile ../../ALL_chr/plink_b_files/chr5_eur_filtered
# --chr 5
# --cojo-file ../../reformated_data_for_cojo/cojo_extracted_file.csv
# --cojo-slct
# --out ../../cojo/chr5/chr5
#
#
# Reading PLINK FAM file from [../../ALL_chr/plink_b_files/chr5_eur_filtered.fam].
# 2504 individuals to be included from [../../ALL_chr/plink_b_files/chr5_eur_filtered.fam].
# Reading PLINK BIM file from [../../ALL_chr/plink_b_files/chr5_eur_filtered.bim].
# 2764 SNPs to be included from [../../ALL_chr/plink_b_files/chr5_eur_filtered.bim].
# 2764 SNPs on chromosome 5 are included in the analysis.
# Reading PLINK BED file from [../../ALL_chr/plink_b_files/chr5_eur_filtered.bed] in SNP-major format ...
# Genotype data for 2504 individuals and 2764 SNPs to be included from [../../ALL_chr/plink_b_files/chr5_eur_filtered.bed].
#
# Reading GWAS summary-level statistics from [../../reformated_data_for_cojo/cojo_extracted_file.csv] ...
# GWAS summary statistics of 49937 SNPs read from [../../reformated_data_for_cojo/cojo_extracted_file.csv].
# Phenotypic variance estimated from summary statistics of all 49937 SNPs: 22.4081 (variance of logit for case-control studies).
# Matching the GWAS meta-analysis results to the genotype data ...
# Calculating allele frequencies ...
# 1182 SNP(s) have large difference of allele frequency between the GWAS summary data and the reference sample. These SNPs have been saved in [../../cojo/chr5/chr5.freq.badsnps].
# 1582 SNPs are matched to the genotype data.
# Calculating the variance of SNP genotypes ...
#
# Performing stepwise model selection on 1582 SNPs to select association signals ... (p cutoff = 5e-08; collinearity cutoff = 0.9)
# (Assuming complete linkage equilibrium between SNPs which are more than 10Mb away from each other)
# 5 associated SNPs have been selected.
# 10 associated SNPs have been selected.
# 15 associated SNPs have been selected.
# 20 associated SNPs have been selected.
# 25 associated SNPs have been selected.
# Finally, 26 associated SNPs are selected.
# Performing joint analysis on all the 26 selected signals ...
# Saving the 26 independent signals to [../../cojo/chr5/chr5.jma.cojo] ...
# Saving the LD structure of 26 independent signals to [../../cojo/chr5/chr5.ldr.cojo] ...
# Saving the conditional analysis results of 1556 remaining SNPs to [../../cojo/chr5/chr5.cma.cojo] ...
# (0 SNPs eliminated by backward selection and 0 SNPs filtered by collinearity test are not included in the output)
#
# Analysis finished at 05:41:32 PST on Mon Feb 24 2025
# Overall computational time: 1.07 sec.

# %% [markdown]
# chr 6

# %% [markdown]
# icog-bioai@dl:/mnt/hdd_2/rediet/hypothesis-generation-demo/data/susie/gcta/gcta-1.94.3-linux-kernel-3-x86_64$ gcta64 --bfile ../../ALL_chr/plink_b_files/chr6_eur_filtered --chr 6  --cojo-file ../../reformated_data_for_cojo/cojo_extracted_file.csv  --cojo-slct --out ../../cojo/chr6/chr6
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.94.1 Linux
# * Built at Dec 16 2024 16:35:13, by GCC 8.3
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 05:42:42 PST on Mon Feb 24 2025.
# Hostname: dl
#
# Accepted options:
# --bfile ../../ALL_chr/plink_b_files/chr6_eur_filtered
# --chr 6
# --cojo-file ../../reformated_data_for_cojo/cojo_extracted_file.csv
# --cojo-slct
# --out ../../cojo/chr6/chr6
#
#
# Reading PLINK FAM file from [../../ALL_chr/plink_b_files/chr6_eur_filtered.fam].
# 2504 individuals to be included from [../../ALL_chr/plink_b_files/chr6_eur_filtered.fam].
# Reading PLINK BIM file from [../../ALL_chr/plink_b_files/chr6_eur_filtered.bim].
# 5260 SNPs to be included from [../../ALL_chr/plink_b_files/chr6_eur_filtered.bim].
# 5260 SNPs on chromosome 6 are included in the analysis.
# Reading PLINK BED file from [../../ALL_chr/plink_b_files/chr6_eur_filtered.bed] in SNP-major format ...
# Genotype data for 2504 individuals and 5260 SNPs to be included from [../../ALL_chr/plink_b_files/chr6_eur_filtered.bed].
#
# Reading GWAS summary-level statistics from [../../reformated_data_for_cojo/cojo_extracted_file.csv] ...
# GWAS summary statistics of 49937 SNPs read from [../../reformated_data_for_cojo/cojo_extracted_file.csv].
# Phenotypic variance estimated from summary statistics of all 49937 SNPs: 22.4081 (variance of logit for case-control studies).
# Matching the GWAS meta-analysis results to the genotype data ...
# Calculating allele frequencies ...
# Warning: can't match the reference alleles of 3 SNPs to those in the genotype data. These SNPs have been saved in [../../cojo/chr6/chr6.badsnps].
# 823 SNP(s) have large difference of allele frequency between the GWAS summary data and the reference sample. These SNPs have been saved in [../../cojo/chr6/chr6.freq.badsnps].
# 4434 SNPs are matched to the genotype data.
# Calculating the variance of SNP genotypes ...
#
# Performing stepwise model selection on 4434 SNPs to select association signals ... (p cutoff = 5e-08; collinearity cutoff = 0.9)
# (Assuming complete linkage equilibrium between SNPs which are more than 10Mb away from each other)
# 5 associated SNPs have been selected.
# 10 associated SNPs have been selected.
# 15 associated SNPs have been selected.
# 20 associated SNPs have been selected.
# 25 associated SNPs have been selected.
# 30 associated SNPs have been selected.
# 35 associated SNPs have been selected.
# 40 associated SNPs have been selected.
# 45 associated SNPs have been selected.
# 50 associated SNPs have been selected.
# Finally, 54 associated SNPs are selected.
# Performing joint analysis on all the 54 selected signals ...
# Saving the 54 independent signals to [../../cojo/chr6/chr6.jma.cojo] ...
# Saving the LD structure of 54 independent signals to [../../cojo/chr6/chr6.ldr.cojo] ...
# Saving the conditional analysis results of 2550 remaining SNPs to [../../cojo/chr6/chr6.cma.cojo] ...
# (2 SNPs eliminated by backward selection and 1828 SNPs filtered by collinearity test are not included in the output)
#
# Analysis finished at 05:42:49 PST on Mon Feb 24 2025
# Overall computational time: 7.34 sec.

# %% [markdown]
# chr 7

# %% [markdown]
# icog-bioai@dl:/mnt/hdd_2/rediet/hypothesis-generation-demo/data/susie/gcta/gcta-1.94.3-linux-kernel-3-x86_64$ ghr7_eur_filtered --chr 7
# cta64 --bfile ../../ALL_chr/plink_b_files/chr7_eur_filtered --chr 7  --cojo-file ../../reformated_data_for_cojo/cojo_extracted_file.csv  --cojo-slct --out ../../cojo/chr7/chr7
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.94.1 Linux
# * Built at Dec 16 2024 16:35:13, by GCC 8.3
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 05:46:39 PST on Mon Feb 24 2025.
# Hostname: dl
#
# Accepted options:
# --bfile ../../ALL_chr/plink_b_files/chr7_eur_filtered
# --chr 7
# --cojo-file ../../reformated_data_for_cojo/cojo_extracted_file.csv
# --cojo-slct
# --out ../../cojo/chr7/chr7
#
#
# Reading PLINK FAM file from [../../ALL_chr/plink_b_files/chr7_eur_filtered.fam].
# 2504 individuals to be included from [../../ALL_chr/plink_b_files/chr7_eur_filtered.fam].
# Reading PLINK BIM file from [../../ALL_chr/plink_b_files/chr7_eur_filtered.bim].
# 1247 SNPs to be included from [../../ALL_chr/plink_b_files/chr7_eur_filtered.bim].
# 1247 SNPs on chromosome 7 are included in the analysis.
# Reading PLINK BED file from [../../ALL_chr/plink_b_files/chr7_eur_filtered.bed] in SNP-major format ...
# Genotype data for 2504 individuals and 1247 SNPs to be included from [../../ALL_chr/plink_b_files/chr7_eur_filtered.bed].
#
# Reading GWAS summary-level statistics from [../../reformated_data_for_cojo/cojo_extracted_file.csv] ...
# GWAS summary statistics of 49937 SNPs read from [../../reformated_data_for_cojo/cojo_extracted_file.csv].
# Phenotypic variance estimated from summary statistics of all 49937 SNPs: 22.4081 (variance of logit for case-control studies).
# Matching the GWAS meta-analysis results to the genotype data ...
# Calculating allele frequencies ...
# 293 SNP(s) have large difference of allele frequency between the GWAS summary data and the reference sample. These SNPs have been saved in [../../cojo/chr7/chr7.freq.badsnps].
# 954 SNPs are matched to the genotype data.
# Calculating the variance of SNP genotypes ...
#
# Performing stepwise model selection on 954 SNPs to select association signals ... (p cutoff = 5e-08; collinearity cutoff = 0.9)
# (Assuming complete linkage equilibrium between SNPs which are more than 10Mb away from each other)
# 5 associated SNPs have been selected.
# 10 associated SNPs have been selected.
# 15 associated SNPs have been selected.
# 20 associated SNPs have been selected.
# Finally, 21 associated SNPs are selected.
# Performing joint analysis on all the 21 selected signals ...
# Saving the 21 independent signals to [../../cojo/chr7/chr7.jma.cojo] ...
# Saving the LD structure of 21 independent signals to [../../cojo/chr7/chr7.ldr.cojo] ...
# Saving the conditional analysis results of 933 remaining SNPs to [../../cojo/chr7/chr7.cma.cojo] ...
# (0 SNPs eliminated by backward selection and 0 SNPs filtered by collinearity test are not included in the output)
#
# Analysis finished at 05:46:39 PST on Mon Feb 24 2025
# Overall computational time: 0.62 sec.

# %% [markdown]
# chr 8

# %% [markdown]
# icog-bioai@dl:/mnt/hdd_2/rediet/hypothesis-generation-demo/data/susie/gcta/gcta-1.94.3-linux-kernel-3-x86_64$ gcta64 --bfile ../../ALL_chr/plink_b_files/chr8_eur_filtered --chr 8  --cojo-file ../../reformated_data_for_cojo/cojo_extracted_file.csv  --cojo-slct --out ../../cojo/chr8/chr8
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.94.1 Linux
# * Built at Dec 16 2024 16:35:13, by GCC 8.3
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 05:48:21 PST on Mon Feb 24 2025.
# Hostname: dl
#
# Accepted options:
# --bfile ../../ALL_chr/plink_b_files/chr8_eur_filtered
# --chr 8
# --cojo-file ../../reformated_data_for_cojo/cojo_extracted_file.csv
# --cojo-slct
# --out ../../cojo/chr8/chr8
#
#
# Reading PLINK FAM file from [../../ALL_chr/plink_b_files/chr8_eur_filtered.fam].
# 2504 individuals to be included from [../../ALL_chr/plink_b_files/chr8_eur_filtered.fam].
# Reading PLINK BIM file from [../../ALL_chr/plink_b_files/chr8_eur_filtered.bim].
# 5223 SNPs to be included from [../../ALL_chr/plink_b_files/chr8_eur_filtered.bim].
# 5223 SNPs on chromosome 8 are included in the analysis.
# Reading PLINK BED file from [../../ALL_chr/plink_b_files/chr8_eur_filtered.bed] in SNP-major format ...
# Genotype data for 2504 individuals and 5223 SNPs to be included from [../../ALL_chr/plink_b_files/chr8_eur_filtered.bed].
#
# Reading GWAS summary-level statistics from [../../reformated_data_for_cojo/cojo_extracted_file.csv] ...
# GWAS summary statistics of 49937 SNPs read from [../../reformated_data_for_cojo/cojo_extracted_file.csv].
# Phenotypic variance estimated from summary statistics of all 49937 SNPs: 22.4081 (variance of logit for case-control studies).
# Matching the GWAS meta-analysis results to the genotype data ...
# Calculating allele frequencies ...
# 1392 SNP(s) have large difference of allele frequency between the GWAS summary data and the reference sample. These SNPs have been saved in [../../cojo/chr8/chr8.freq.badsnps].
# 3831 SNPs are matched to the genotype data.
# Calculating the variance of SNP genotypes ...
#
# Performing stepwise model selection on 3831 SNPs to select association signals ... (p cutoff = 5e-08; collinearity cutoff = 0.9)
# (Assuming complete linkage equilibrium between SNPs which are more than 10Mb away from each other)
# 5 associated SNPs have been selected.
# 10 associated SNPs have been selected.
# 15 associated SNPs have been selected.
# 20 associated SNPs have been selected.
# Finally, 24 associated SNPs are selected.
# Performing joint analysis on all the 24 selected signals ...
# Saving the 24 independent signals to [../../cojo/chr8/chr8.jma.cojo] ...
# Saving the LD structure of 24 independent signals to [../../cojo/chr8/chr8.ldr.cojo] ...
# Saving the conditional analysis results of 3806 remaining SNPs to [../../cojo/chr8/chr8.cma.cojo] ...
# (1 SNPs eliminated by backward selection and 0 SNPs filtered by collinearity test are not included in the output)
#
# Analysis finished at 05:48:23 PST on Mon Feb 24 2025
# Overall computational time: 2.42 sec.

# %% [markdown]
# chr 9

# %% [markdown]
# icog-bioai@dl:/mnt/hdd_2/rediet/hypothesis-generation-demo/data/susie/gcta/gcta-1.94.3-linux-kernel-3-x86_64$ gcta64 --bfile ../../ALL_chr/plink_b_files/chr9_eur_filtered --chr 9  --cojo-file ../../reformated_data_for_cojo/cojo_extracted_file.csv  --cojo-slct --out ../../cojo/chr9/chr9
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.94.1 Linux
# * Built at Dec 16 2024 16:35:13, by GCC 8.3
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 05:49:42 PST on Mon Feb 24 2025.
# Hostname: dl
#
# Accepted options:
# --bfile ../../ALL_chr/plink_b_files/chr9_eur_filtered
# --chr 9
# --cojo-file ../../reformated_data_for_cojo/cojo_extracted_file.csv
# --cojo-slct
# --out ../../cojo/chr9/chr9
#
#
# Reading PLINK FAM file from [../../ALL_chr/plink_b_files/chr9_eur_filtered.fam].
# 2504 individuals to be included from [../../ALL_chr/plink_b_files/chr9_eur_filtered.fam].
# Reading PLINK BIM file from [../../ALL_chr/plink_b_files/chr9_eur_filtered.bim].
# 1906 SNPs to be included from [../../ALL_chr/plink_b_files/chr9_eur_filtered.bim].
# 1906 SNPs on chromosome 9 are included in the analysis.
# Reading PLINK BED file from [../../ALL_chr/plink_b_files/chr9_eur_filtered.bed] in SNP-major format ...
# Genotype data for 2504 individuals and 1906 SNPs to be included from [../../ALL_chr/plink_b_files/chr9_eur_filtered.bed].
#
# Reading GWAS summary-level statistics from [../../reformated_data_for_cojo/cojo_extracted_file.csv] ...
# GWAS summary statistics of 49937 SNPs read from [../../reformated_data_for_cojo/cojo_extracted_file.csv].
# Phenotypic variance estimated from summary statistics of all 49937 SNPs: 22.4081 (variance of logit for case-control studies).
# Matching the GWAS meta-analysis results to the genotype data ...
# Calculating allele frequencies ...
# 484 SNP(s) have large difference of allele frequency between the GWAS summary data and the reference sample. These SNPs have been saved in [../../cojo/chr9/chr9.freq.badsnps].
# 1422 SNPs are matched to the genotype data.
# Calculating the variance of SNP genotypes ...
#
# Performing stepwise model selection on 1422 SNPs to select association signals ... (p cutoff = 5e-08; collinearity cutoff = 0.9)
# (Assuming complete linkage equilibrium between SNPs which are more than 10Mb away from each other)
# 5 associated SNPs have been selected.
# 10 associated SNPs have been selected.
# 15 associated SNPs have been selected.
# Finally, 18 associated SNPs are selected.
# Performing joint analysis on all the 18 selected signals ...
# Saving the 18 independent signals to [../../cojo/chr9/chr9.jma.cojo] ...
# Saving the LD structure of 18 independent signals to [../../cojo/chr9/chr9.ldr.cojo] ...
# Saving the conditional analysis results of 1404 remaining SNPs to [../../cojo/chr9/chr9.cma.cojo] ...
# (0 SNPs eliminated by backward selection and 0 SNPs filtered by collinearity test are not included in the output)
#
# Analysis finished at 05:49:43 PST on Mon Feb 24 2025
# Overall computational time: 0.84 sec.

# %% [markdown]
# chr 10

# %% [markdown]
# icog-bioai@dl:/mnt/hdd_2/rediet/hypothesis-generation-demo/data/susie/gcta/gcta-1.94.3-linux-kernel-3-x86_64$ gcta64 --bfile ../../ALL_chr/plink_b_files/chr10_eur_filtered --chr 10  --cojo-file ../../reformated_data_for_cojo/cojo_extracted_file.csv  --cojo-slct --out ../../cojo/chr10/chr10
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.94.1 Linux
# * Built at Dec 16 2024 16:35:13, by GCC 8.3
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 05:50:49 PST on Mon Feb 24 2025.
# Hostname: dl
#
# Accepted options:
# --bfile ../../ALL_chr/plink_b_files/chr10_eur_filtered
# --chr 10
# --cojo-file ../../reformated_data_for_cojo/cojo_extracted_file.csv
# --cojo-slct
# --out ../../cojo/chr10/chr10
#
#
# Reading PLINK FAM file from [../../ALL_chr/plink_b_files/chr10_eur_filtered.fam].
# 2504 individuals to be included from [../../ALL_chr/plink_b_files/chr10_eur_filtered.fam].
# Reading PLINK BIM file from [../../ALL_chr/plink_b_files/chr10_eur_filtered.bim].
# 1025 SNPs to be included from [../../ALL_chr/plink_b_files/chr10_eur_filtered.bim].
# 1025 SNPs on chromosome 10 are included in the analysis.
# Reading PLINK BED file from [../../ALL_chr/plink_b_files/chr10_eur_filtered.bed] in SNP-major format ...
# Genotype data for 2504 individuals and 1025 SNPs to be included from [../../ALL_chr/plink_b_files/chr10_eur_filtered.bed].
#
# Reading GWAS summary-level statistics from [../../reformated_data_for_cojo/cojo_extracted_file.csv] ...
# GWAS summary statistics of 49937 SNPs read from [../../reformated_data_for_cojo/cojo_extracted_file.csv].
# Phenotypic variance estimated from summary statistics of all 49937 SNPs: 22.4081 (variance of logit for case-control studies).
# Matching the GWAS meta-analysis results to the genotype data ...
# Calculating allele frequencies ...
# 212 SNP(s) have large difference of allele frequency between the GWAS summary data and the reference sample. These SNPs have been saved in [../../cojo/chr10/chr10.freq.badsnps].
# 813 SNPs are matched to the genotype data.
# Calculating the variance of SNP genotypes ...
#
# Performing stepwise model selection on 813 SNPs to select association signals ... (p cutoff = 5e-08; collinearity cutoff = 0.9)
# (Assuming complete linkage equilibrium between SNPs which are more than 10Mb away from each other)
# 5 associated SNPs have been selected.
# 10 associated SNPs have been selected.
# 15 associated SNPs have been selected.
# 20 associated SNPs have been selected.
# Finally, 23 associated SNPs are selected.
# Performing joint analysis on all the 23 selected signals ...
# Saving the 23 independent signals to [../../cojo/chr10/chr10.jma.cojo] ...
# Saving the LD structure of 23 independent signals to [../../cojo/chr10/chr10.ldr.cojo] ...
# Saving the conditional analysis results of 790 remaining SNPs to [../../cojo/chr10/chr10.cma.cojo] ...
# (0 SNPs eliminated by backward selection and 0 SNPs filtered by collinearity test are not included in the output)
#
# Analysis finished at 05:50:49 PST on Mon Feb 24 2025
# Overall computational time: 0.50 sec.

# %% [markdown]
# chr 11

# %% [markdown]
# icog-bioai@dl:/mnt/hdd_2/rediet/hypothesis-generation-demo/data/susie/gcta/gcta-1.94.3-linux-kernel-3-x86_64$ gcta64 --bfile ../../ALL_chr/plink_b_files/chr11_eur_filtered --chr 11  --cojo-file ../../reformated_data_for_cojo/cojo_extracted_file.csv  --cojo-slct --out ../../cojo/chr11/chr11
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.94.1 Linux
# * Built at Dec 16 2024 16:35:13, by GCC 8.3
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 05:51:43 PST on Mon Feb 24 2025.
# Hostname: dl
#
# Accepted options:
# --bfile ../../ALL_chr/plink_b_files/chr11_eur_filtered
# --chr 11
# --cojo-file ../../reformated_data_for_cojo/cojo_extracted_file.csv
# --cojo-slct
# --out ../../cojo/chr11/chr11
#
#
# Reading PLINK FAM file from [../../ALL_chr/plink_b_files/chr11_eur_filtered.fam].
# 2504 individuals to be included from [../../ALL_chr/plink_b_files/chr11_eur_filtered.fam].
# Reading PLINK BIM file from [../../ALL_chr/plink_b_files/chr11_eur_filtered.bim].
# 2187 SNPs to be included from [../../ALL_chr/plink_b_files/chr11_eur_filtered.bim].
# 2187 SNPs on chromosome 11 are included in the analysis.
# Reading PLINK BED file from [../../ALL_chr/plink_b_files/chr11_eur_filtered.bed] in SNP-major format ...
# Genotype data for 2504 individuals and 2187 SNPs to be included from [../../ALL_chr/plink_b_files/chr11_eur_filtered.bed].
#
# Reading GWAS summary-level statistics from [../../reformated_data_for_cojo/cojo_extracted_file.csv] ...
# GWAS summary statistics of 49937 SNPs read from [../../reformated_data_for_cojo/cojo_extracted_file.csv].
# Phenotypic variance estimated from summary statistics of all 49937 SNPs: 22.4081 (variance of logit for case-control studies).
# Matching the GWAS meta-analysis results to the genotype data ...
# Calculating allele frequencies ...
# 361 SNP(s) have large difference of allele frequency between the GWAS summary data and the reference sample. These SNPs have been saved in [../../cojo/chr11/chr11.freq.badsnps].
# 1826 SNPs are matched to the genotype data.
# Calculating the variance of SNP genotypes ...
#
# Performing stepwise model selection on 1826 SNPs to select association signals ... (p cutoff = 5e-08; collinearity cutoff = 0.9)
# (Assuming complete linkage equilibrium between SNPs which are more than 10Mb away from each other)
# 5 associated SNPs have been selected.
# 10 associated SNPs have been selected.
# 15 associated SNPs have been selected.
# 20 associated SNPs have been selected.
# 25 associated SNPs have been selected.
# 30 associated SNPs have been selected.
# Finally, 30 associated SNPs are selected.
# Performing joint analysis on all the 30 selected signals ...
# Saving the 30 independent signals to [../../cojo/chr11/chr11.jma.cojo] ...
# Saving the LD structure of 30 independent signals to [../../cojo/chr11/chr11.ldr.cojo] ...
# Saving the conditional analysis results of 1796 remaining SNPs to [../../cojo/chr11/chr11.cma.cojo] ...
# (0 SNPs eliminated by backward selection and 0 SNPs filtered by collinearity test are not included in the output)
#
# Analysis finished at 05:51:44 PST on Mon Feb 24 2025
# Overall computational time: 1.26 sec.

# %% [markdown]
# chr 12

# %% [markdown]
# icog-bioai@dl:/mnt/hdd_2/rediet/hypothesis-generation-demo/data/susie/gcta/gcta-1.94.3-linux-kernel-3-x86_64$ gcta64 --bfile ../../ALL_chr/plink_b_files/chr12_eur_filtered --chr 12  --cojo-file ../../reformated_data_for_cojo/cojo_extracted_file.csv  --cojo-slct --out ../../cojo/chr12/chr12
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.94.1 Linux
# * Built at Dec 16 2024 16:35:13, by GCC 8.3
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 05:52:44 PST on Mon Feb 24 2025.
# Hostname: dl
#
# Accepted options:
# --bfile ../../ALL_chr/plink_b_files/chr12_eur_filtered
# --chr 12
# --cojo-file ../../reformated_data_for_cojo/cojo_extracted_file.csv
# --cojo-slct
# --out ../../cojo/chr12/chr12
#
#
# Reading PLINK FAM file from [../../ALL_chr/plink_b_files/chr12_eur_filtered.fam].
# 2504 individuals to be included from [../../ALL_chr/plink_b_files/chr12_eur_filtered.fam].
# Reading PLINK BIM file from [../../ALL_chr/plink_b_files/chr12_eur_filtered.bim].
# 1747 SNPs to be included from [../../ALL_chr/plink_b_files/chr12_eur_filtered.bim].
# 1747 SNPs on chromosome 12 are included in the analysis.
# Reading PLINK BED file from [../../ALL_chr/plink_b_files/chr12_eur_filtered.bed] in SNP-major format ...
# Genotype data for 2504 individuals and 1747 SNPs to be included from [../../ALL_chr/plink_b_files/chr12_eur_filtered.bed].
#
# Reading GWAS summary-level statistics from [../../reformated_data_for_cojo/cojo_extracted_file.csv] ...
# GWAS summary statistics of 49937 SNPs read from [../../reformated_data_for_cojo/cojo_extracted_file.csv].
# Phenotypic variance estimated from summary statistics of all 49937 SNPs: 22.4081 (variance of logit for case-control studies).
# Matching the GWAS meta-analysis results to the genotype data ...
# Calculating allele frequencies ...
# 510 SNP(s) have large difference of allele frequency between the GWAS summary data and the reference sample. These SNPs have been saved in [../../cojo/chr12/chr12.freq.badsnps].
# 1237 SNPs are matched to the genotype data.
# Calculating the variance of SNP genotypes ...
#
# Performing stepwise model selection on 1237 SNPs to select association signals ... (p cutoff = 5e-08; collinearity cutoff = 0.9)
# (Assuming complete linkage equilibrium between SNPs which are more than 10Mb away from each other)
# 5 associated SNPs have been selected.
# 10 associated SNPs have been selected.
# 15 associated SNPs have been selected.
# 20 associated SNPs have been selected.
# Finally, 20 associated SNPs are selected.
# Performing joint analysis on all the 20 selected signals ...
# Saving the 20 independent signals to [../../cojo/chr12/chr12.jma.cojo] ...
# Saving the LD structure of 20 independent signals to [../../cojo/chr12/chr12.ldr.cojo] ...
# Saving the conditional analysis results of 1217 remaining SNPs to [../../cojo/chr12/chr12.cma.cojo] ...
# (0 SNPs eliminated by backward selection and 0 SNPs filtered by collinearity test are not included in the output)
#
# Analysis finished at 05:52:45 PST on Mon Feb 24 2025
# Overall computational time: 0.68 sec.

# %% [markdown]
# chr13

# %% [markdown]
# icog-bioai@dl:/mnt/hdd_2/rediet/hypothesis-generation-demo/data/susie/gcta/gcta-1.94.3-linux-kernel-3-x86_64$ gcta64 --bfile ../../ALL_chr/plink_b_files/chr13_eur_filtered --chr 13  --cojo-file ../../reformated_data_for_cojo/cojo_extracted_file.csv  --cojo-slct --out ../../cojo/chr13/chr13
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.94.1 Linux
# * Built at Dec 16 2024 16:35:13, by GCC 8.3
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 05:54:28 PST on Mon Feb 24 2025.
# Hostname: dl
#
# Accepted options:
# --bfile ../../ALL_chr/plink_b_files/chr13_eur_filtered
# --chr 13
# --cojo-file ../../reformated_data_for_cojo/cojo_extracted_file.csv
# --cojo-slct
# --out ../../cojo/chr13/chr13
#
#
# Reading PLINK FAM file from [../../ALL_chr/plink_b_files/chr13_eur_filtered.fam].
# 2504 individuals to be included from [../../ALL_chr/plink_b_files/chr13_eur_filtered.fam].
# Reading PLINK BIM file from [../../ALL_chr/plink_b_files/chr13_eur_filtered.bim].
# 1650 SNPs to be included from [../../ALL_chr/plink_b_files/chr13_eur_filtered.bim].
# 1650 SNPs on chromosome 13 are included in the analysis.
# Reading PLINK BED file from [../../ALL_chr/plink_b_files/chr13_eur_filtered.bed] in SNP-major format ...
# Genotype data for 2504 individuals and 1650 SNPs to be included from [../../ALL_chr/plink_b_files/chr13_eur_filtered.bed].
#
# Reading GWAS summary-level statistics from [../../reformated_data_for_cojo/cojo_extracted_file.csv] ...
# GWAS summary statistics of 49937 SNPs read from [../../reformated_data_for_cojo/cojo_extracted_file.csv].
# Phenotypic variance estimated from summary statistics of all 49937 SNPs: 22.4081 (variance of logit for case-control studies).
# Matching the GWAS meta-analysis results to the genotype data ...
# Calculating allele frequencies ...
# 197 SNP(s) have large difference of allele frequency between the GWAS summary data and the reference sample. These SNPs have been saved in [../../cojo/chr13/chr13.freq.badsnps].
# 1453 SNPs are matched to the genotype data.
# Calculating the variance of SNP genotypes ...
#
# Performing stepwise model selection on 1453 SNPs to select association signals ... (p cutoff = 5e-08; collinearity cutoff = 0.9)
# (Assuming complete linkage equilibrium between SNPs which are more than 10Mb away from each other)
# 5 associated SNPs have been selected.
# 10 associated SNPs have been selected.
# 15 associated SNPs have been selected.
# 20 associated SNPs have been selected.
# Finally, 22 associated SNPs are selected.
# Performing joint analysis on all the 22 selected signals ...
# Saving the 22 independent signals to [../../cojo/chr13/chr13.jma.cojo] ...
# Saving the LD structure of 22 independent signals to [../../cojo/chr13/chr13.ldr.cojo] ...
# Saving the conditional analysis results of 1431 remaining SNPs to [../../cojo/chr13/chr13.cma.cojo] ...
# (0 SNPs eliminated by backward selection and 0 SNPs filtered by collinearity test are not included in the output)
#
# Analysis finished at 05:54:29 PST on Mon Feb 24 2025
# Overall computational time: 0.80 sec.

# %% [markdown]
# chr14

# %% [markdown]
# icog-bioai@dl:/mnt/hdd_2/rediet/hypothesis-generation-demo/data/susie/gcta/gcta-1.94.3-linux-kernel-3-x86_64$ gcta64 --bfile ../../ALL_chr/plink_b_files/chr14_eur_filtered --chr 14  --cojo-file ../../reformated_data_for_cojo/cojo_extracted_file.csv  --cojo-slct --out ../../cojo/chr14/chr14
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.94.1 Linux
# * Built at Dec 16 2024 16:35:13, by GCC 8.3
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 05:56:32 PST on Mon Feb 24 2025.
# Hostname: dl
#
# Accepted options:
# --bfile ../../ALL_chr/plink_b_files/chr14_eur_filtered
# --chr 14
# --cojo-file ../../reformated_data_for_cojo/cojo_extracted_file.csv
# --cojo-slct
# --out ../../cojo/chr14/chr14
#
#
# Reading PLINK FAM file from [../../ALL_chr/plink_b_files/chr14_eur_filtered.fam].
# 2504 individuals to be included from [../../ALL_chr/plink_b_files/chr14_eur_filtered.fam].
# Reading PLINK BIM file from [../../ALL_chr/plink_b_files/chr14_eur_filtered.bim].
# 1576 SNPs to be included from [../../ALL_chr/plink_b_files/chr14_eur_filtered.bim].
# 1576 SNPs on chromosome 14 are included in the analysis.
# Reading PLINK BED file from [../../ALL_chr/plink_b_files/chr14_eur_filtered.bed] in SNP-major format ...
# Genotype data for 2504 individuals and 1576 SNPs to be included from [../../ALL_chr/plink_b_files/chr14_eur_filtered.bed].
#
# Reading GWAS summary-level statistics from [../../reformated_data_for_cojo/cojo_extracted_file.csv] ...
# GWAS summary statistics of 49937 SNPs read from [../../reformated_data_for_cojo/cojo_extracted_file.csv].
# Phenotypic variance estimated from summary statistics of all 49937 SNPs: 22.4081 (variance of logit for case-control studies).
# Matching the GWAS meta-analysis results to the genotype data ...
# Calculating allele frequencies ...
# 410 SNP(s) have large difference of allele frequency between the GWAS summary data and the reference sample. These SNPs have been saved in [../../cojo/chr14/chr14.freq.badsnps].
# 1166 SNPs are matched to the genotype data.
# Calculating the variance of SNP genotypes ...
#
# Performing stepwise model selection on 1166 SNPs to select association signals ... (p cutoff = 5e-08; collinearity cutoff = 0.9)
# (Assuming complete linkage equilibrium between SNPs which are more than 10Mb away from each other)
# 5 associated SNPs have been selected.
# 10 associated SNPs have been selected.
# 15 associated SNPs have been selected.
# Finally, 16 associated SNPs are selected.
# Performing joint analysis on all the 16 selected signals ...
# Saving the 16 independent signals to [../../cojo/chr14/chr14.jma.cojo] ...
# Saving the LD structure of 16 independent signals to [../../cojo/chr14/chr14.ldr.cojo] ...
# Saving the conditional analysis results of 1150 remaining SNPs to [../../cojo/chr14/chr14.cma.cojo] ...
# (0 SNPs eliminated by backward selection and 0 SNPs filtered by collinearity test are not included in the output)
#
# Analysis finished at 05:56:32 PST on Mon Feb 24 2025
# Overall computational time: 0.62 sec.

# %% [markdown]
# chr15

# %% [markdown]
# icog-bioai@dl:/mnt/hdd_2/rediet/hypothesis-generation-demo/data/susie/gcta/gcta-1.94.3-linux-kernel-3-x86_64$ gcta64 --bfile ../../ALL_chr/plink_b_files/chr15_eur_filtered --chr 15  --cojo-file ../../reformated_data_for_cojo/cojo_extracted_file.csv  --cojo-slct --out ../../cojo/chr15/chr15
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.94.1 Linux
# * Built at Dec 16 2024 16:35:13, by GCC 8.3
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 05:57:55 PST on Mon Feb 24 2025.
# Hostname: dl
#
# Accepted options:
# --bfile ../../ALL_chr/plink_b_files/chr15_eur_filtered
# --chr 15
# --cojo-file ../../reformated_data_for_cojo/cojo_extracted_file.csv
# --cojo-slct
# --out ../../cojo/chr15/chr15
#
#
# Reading PLINK FAM file from [../../ALL_chr/plink_b_files/chr15_eur_filtered.fam].
# 2504 individuals to be included from [../../ALL_chr/plink_b_files/chr15_eur_filtered.fam].
# Reading PLINK BIM file from [../../ALL_chr/plink_b_files/chr15_eur_filtered.bim].
# 977 SNPs to be included from [../../ALL_chr/plink_b_files/chr15_eur_filtered.bim].
# 977 SNPs on chromosome 15 are included in the analysis.
# Reading PLINK BED file from [../../ALL_chr/plink_b_files/chr15_eur_filtered.bed] in SNP-major format ...
# Genotype data for 2504 individuals and 977 SNPs to be included from [../../ALL_chr/plink_b_files/chr15_eur_filtered.bed].
#
# Reading GWAS summary-level statistics from [../../reformated_data_for_cojo/cojo_extracted_file.csv] ...
# GWAS summary statistics of 49937 SNPs read from [../../reformated_data_for_cojo/cojo_extracted_file.csv].
# Phenotypic variance estimated from summary statistics of all 49937 SNPs: 22.4081 (variance of logit for case-control studies).
# Matching the GWAS meta-analysis results to the genotype data ...
# Calculating allele frequencies ...
# 117 SNP(s) have large difference of allele frequency between the GWAS summary data and the reference sample. These SNPs have been saved in [../../cojo/chr15/chr15.freq.badsnps].
# 860 SNPs are matched to the genotype data.
# Calculating the variance of SNP genotypes ...
#
# Performing stepwise model selection on 860 SNPs to select association signals ... (p cutoff = 5e-08; collinearity cutoff = 0.9)
# (Assuming complete linkage equilibrium between SNPs which are more than 10Mb away from each other)
# 5 associated SNPs have been selected.
# 10 associated SNPs have been selected.
# 15 associated SNPs have been selected.
# Finally, 16 associated SNPs are selected.
# Performing joint analysis on all the 16 selected signals ...
# Saving the 16 independent signals to [../../cojo/chr15/chr15.jma.cojo] ...
# Saving the LD structure of 16 independent signals to [../../cojo/chr15/chr15.ldr.cojo] ...
# Saving the conditional analysis results of 844 remaining SNPs to [../../cojo/chr15/chr15.cma.cojo] ...
# (0 SNPs eliminated by backward selection and 0 SNPs filtered by collinearity test are not included in the output)
#
# Analysis finished at 05:57:55 PST on Mon Feb 24 2025
# Overall computational time: 0.54 sec.

# %% [markdown]
# chr16

# %% [markdown]
# icog-bioai@dl:/mnt/hdd_2/rediet/hypothesis-generation-demo/data/susie/gcta/gcta-1.94.3-linux-kernel-3-x86_64$ gcta64 --bfile ../../ALL_chr/plink_b_files/chr16_eur_filtered --chr 16  --cojo-file ../../reformated_data_for_cojo/cojo_extracted_file.csv  --cojo-slct --out ../../cojo/chr16/chr16
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.94.1 Linux
# * Built at Dec 16 2024 16:35:13, by GCC 8.3
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 05:58:54 PST on Mon Feb 24 2025.
# Hostname: dl
#
# Accepted options:
# --bfile ../../ALL_chr/plink_b_files/chr16_eur_filtered
# --chr 16
# --cojo-file ../../reformated_data_for_cojo/cojo_extracted_file.csv
# --cojo-slct
# --out ../../cojo/chr16/chr16
#
#
# Reading PLINK FAM file from [../../ALL_chr/plink_b_files/chr16_eur_filtered.fam].
# 2504 individuals to be included from [../../ALL_chr/plink_b_files/chr16_eur_filtered.fam].
# Reading PLINK BIM file from [../../ALL_chr/plink_b_files/chr16_eur_filtered.bim].
# 2415 SNPs to be included from [../../ALL_chr/plink_b_files/chr16_eur_filtered.bim].
# 2415 SNPs on chromosome 16 are included in the analysis.
# Reading PLINK BED file from [../../ALL_chr/plink_b_files/chr16_eur_filtered.bed] in SNP-major format ...
# Genotype data for 2504 individuals and 2415 SNPs to be included from [../../ALL_chr/plink_b_files/chr16_eur_filtered.bed].
#
# Reading GWAS summary-level statistics from [../../reformated_data_for_cojo/cojo_extracted_file.csv] ...
# GWAS summary statistics of 49937 SNPs read from [../../reformated_data_for_cojo/cojo_extracted_file.csv].
# Phenotypic variance estimated from summary statistics of all 49937 SNPs: 22.4081 (variance of logit for case-control studies).
# Matching the GWAS meta-analysis results to the genotype data ...
# Calculating allele frequencies ...
# 557 SNP(s) have large difference of allele frequency between the GWAS summary data and the reference sample. These SNPs have been saved in [../../cojo/chr16/chr16.freq.badsnps].
# 1858 SNPs are matched to the genotype data.
# Calculating the variance of SNP genotypes ...
#
# Performing stepwise model selection on 1858 SNPs to select association signals ... (p cutoff = 5e-08; collinearity cutoff = 0.9)
# (Assuming complete linkage equilibrium between SNPs which are more than 10Mb away from each other)
# 5 associated SNPs have been selected.
# 10 associated SNPs have been selected.
# 15 associated SNPs have been selected.
# 20 associated SNPs have been selected.
# 25 associated SNPs have been selected.
# 30 associated SNPs have been selected.
# Finally, 30 associated SNPs are selected.
# Performing joint analysis on all the 30 selected signals ...
# Saving the 30 independent signals to [../../cojo/chr16/chr16.jma.cojo] ...
# Saving the LD structure of 30 independent signals to [../../cojo/chr16/chr16.ldr.cojo] ...
# Saving the conditional analysis results of 1822 remaining SNPs to [../../cojo/chr16/chr16.cma.cojo] ...
# (1 SNPs eliminated by backward selection and 5 SNPs filtered by collinearity test are not included in the output)
#
# Analysis finished at 05:58:56 PST on Mon Feb 24 2025
# Overall computational time: 1.34 sec.

# %% [markdown]
# chr17

# %% [markdown]
# icog-bioai@dl:/mnt/hdd_2/rediet/hypothesis-generation-demo/data/susie/gcta/gcta-1.94.3-linux-kernel-3-x86_64$ gcta64 --bfile ../../ALL_chr/plink_b_files/chr17_eur_filtered --chr 17  --cojo-file ../../reformated_data_for_cojo/cojo_extracted_file.csv  --cojo-slct --out ../../cojo/chr17/chr17
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.94.1 Linux
# * Built at Dec 16 2024 16:35:13, by GCC 8.3
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 05:59:39 PST on Mon Feb 24 2025.
# Hostname: dl
#
# Accepted options:
# --bfile ../../ALL_chr/plink_b_files/chr17_eur_filtered
# --chr 17
# --cojo-file ../../reformated_data_for_cojo/cojo_extracted_file.csv
# --cojo-slct
# --out ../../cojo/chr17/chr17
#
#
# Reading PLINK FAM file from [../../ALL_chr/plink_b_files/chr17_eur_filtered.fam].
# 2504 individuals to be included from [../../ALL_chr/plink_b_files/chr17_eur_filtered.fam].
# Reading PLINK BIM file from [../../ALL_chr/plink_b_files/chr17_eur_filtered.bim].
# 1427 SNPs to be included from [../../ALL_chr/plink_b_files/chr17_eur_filtered.bim].
# 1427 SNPs on chromosome 17 are included in the analysis.
# Reading PLINK BED file from [../../ALL_chr/plink_b_files/chr17_eur_filtered.bed] in SNP-major format ...
# Genotype data for 2504 individuals and 1427 SNPs to be included from [../../ALL_chr/plink_b_files/chr17_eur_filtered.bed].
#
# Reading GWAS summary-level statistics from [../../reformated_data_for_cojo/cojo_extracted_file.csv] ...
# GWAS summary statistics of 49937 SNPs read from [../../reformated_data_for_cojo/cojo_extracted_file.csv].
# Phenotypic variance estimated from summary statistics of all 49937 SNPs: 22.4081 (variance of logit for case-control studies).
# Matching the GWAS meta-analysis results to the genotype data ...
# Calculating allele frequencies ...
# 275 SNP(s) have large difference of allele frequency between the GWAS summary data and the reference sample. These SNPs have been saved in [../../cojo/chr17/chr17.freq.badsnps].
# 1152 SNPs are matched to the genotype data.
# Calculating the variance of SNP genotypes ...
#
# Performing stepwise model selection on 1152 SNPs to select association signals ... (p cutoff = 5e-08; collinearity cutoff = 0.9)
# (Assuming complete linkage equilibrium between SNPs which are more than 10Mb away from each other)
# 5 associated SNPs have been selected.
# 10 associated SNPs have been selected.
# 15 associated SNPs have been selected.
# 20 associated SNPs have been selected.
# Finally, 22 associated SNPs are selected.
# Performing joint analysis on all the 22 selected signals ...
# Saving the 22 independent signals to [../../cojo/chr17/chr17.jma.cojo] ...
# Saving the LD structure of 22 independent signals to [../../cojo/chr17/chr17.ldr.cojo] ...
# Saving the conditional analysis results of 1130 remaining SNPs to [../../cojo/chr17/chr17.cma.cojo] ...
# (0 SNPs eliminated by backward selection and 0 SNPs filtered by collinearity test are not included in the output)
#
# Analysis finished at 05:59:39 PST on Mon Feb 24 2025
# Overall computational time: 0.62 sec.

# %% [markdown]
# chr18

# %% [markdown]
# icog-bioai@dl:/mnt/hdd_2/rediet/hypothesis-generation-demo/data/susie/gcta/gcta-1.94.3-linux-kernel-3-x86_64$ gcta64 --bfile ../../ALL_chr/plink_b_files/chr18_eur_filtered --chr 18  --cojo-file ../../reformated_data_for_cojo/cojo_extracted_file.csv  --cojo-slct --out ../../cojo/chr18/chr18
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.94.1 Linux
# * Built at Dec 16 2024 16:35:13, by GCC 8.3
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 06:00:41 PST on Mon Feb 24 2025.
# Hostname: dl
#
# Accepted options:
# --bfile ../../ALL_chr/plink_b_files/chr18_eur_filtered
# --chr 18
# --cojo-file ../../reformated_data_for_cojo/cojo_extracted_file.csv
# --cojo-slct
# --out ../../cojo/chr18/chr18
#
#
# Reading PLINK FAM file from [../../ALL_chr/plink_b_files/chr18_eur_filtered.fam].
# 2504 individuals to be included from [../../ALL_chr/plink_b_files/chr18_eur_filtered.fam].
# Reading PLINK BIM file from [../../ALL_chr/plink_b_files/chr18_eur_filtered.bim].
# 1124 SNPs to be included from [../../ALL_chr/plink_b_files/chr18_eur_filtered.bim].
# 1124 SNPs on chromosome 18 are included in the analysis.
# Reading PLINK BED file from [../../ALL_chr/plink_b_files/chr18_eur_filtered.bed] in SNP-major format ...
# Genotype data for 2504 individuals and 1124 SNPs to be included from [../../ALL_chr/plink_b_files/chr18_eur_filtered.bed].
#
# Reading GWAS summary-level statistics from [../../reformated_data_for_cojo/cojo_extracted_file.csv] ...
# GWAS summary statistics of 49937 SNPs read from [../../reformated_data_for_cojo/cojo_extracted_file.csv].
# Phenotypic variance estimated from summary statistics of all 49937 SNPs: 22.4081 (variance of logit for case-control studies).
# Matching the GWAS meta-analysis results to the genotype data ...
# Calculating allele frequencies ...
# Warning: can't match the reference alleles of 1 SNPs to those in the genotype data. These SNPs have been saved in [../../cojo/chr18/chr18.badsnps].
# 124 SNP(s) have large difference of allele frequency between the GWAS summary data and the reference sample. These SNPs have been saved in [../../cojo/chr18/chr18.freq.badsnps].
# 999 SNPs are matched to the genotype data.
# Calculating the variance of SNP genotypes ...
#
# Performing stepwise model selection on 999 SNPs to select association signals ... (p cutoff = 5e-08; collinearity cutoff = 0.9)
# (Assuming complete linkage equilibrium between SNPs which are more than 10Mb away from each other)
# 5 associated SNPs have been selected.
# 10 associated SNPs have been selected.
# 15 associated SNPs have been selected.
# 20 associated SNPs have been selected.
# Finally, 23 associated SNPs are selected.
# Performing joint analysis on all the 23 selected signals ...
# Saving the 23 independent signals to [../../cojo/chr18/chr18.jma.cojo] ...
# Saving the LD structure of 23 independent signals to [../../cojo/chr18/chr18.ldr.cojo] ...
# Saving the conditional analysis results of 976 remaining SNPs to [../../cojo/chr18/chr18.cma.cojo] ...
# (0 SNPs eliminated by backward selection and 0 SNPs filtered by collinearity test are not included in the output)
#
# Analysis finished at 06:00:42 PST on Mon Feb 24 2025
# Overall computational time: 0.66 sec.

# %% [markdown]
# chr19

# %% [markdown]
# icog-bioai@dl:/mnt/hdd_2/rediet/hypothesis-generation-demo/data/susie/gcta/gcta-1.94.3-linux-kernel-3-x86_64$ gcta64 --bfile ../../ALL_chr/plink_b_files/chr19_eur_filtered --chr 19  --cojo-file ../../reformated_data_for_cojo/cojo_extracted_file.csv  --cojo-slct --out ../../cojo/chr19/chr19
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.94.1 Linux
# * Built at Dec 16 2024 16:35:13, by GCC 8.3
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 06:01:46 PST on Mon Feb 24 2025.
# Hostname: dl
#
# Accepted options:
# --bfile ../../ALL_chr/plink_b_files/chr19_eur_filtered
# --chr 19
# --cojo-file ../../reformated_data_for_cojo/cojo_extracted_file.csv
# --cojo-slct
# --out ../../cojo/chr19/chr19
#
#
# Reading PLINK FAM file from [../../ALL_chr/plink_b_files/chr19_eur_filtered.fam].
# 2504 individuals to be included from [../../ALL_chr/plink_b_files/chr19_eur_filtered.fam].
# Reading PLINK BIM file from [../../ALL_chr/plink_b_files/chr19_eur_filtered.bim].
# 989 SNPs to be included from [../../ALL_chr/plink_b_files/chr19_eur_filtered.bim].
# 989 SNPs on chromosome 19 are included in the analysis.
# Reading PLINK BED file from [../../ALL_chr/plink_b_files/chr19_eur_filtered.bed] in SNP-major format ...
# Genotype data for 2504 individuals and 989 SNPs to be included from [../../ALL_chr/plink_b_files/chr19_eur_filtered.bed].
#
# Reading GWAS summary-level statistics from [../../reformated_data_for_cojo/cojo_extracted_file.csv] ...
# GWAS summary statistics of 49937 SNPs read from [../../reformated_data_for_cojo/cojo_extracted_file.csv].
# Phenotypic variance estimated from summary statistics of all 49937 SNPs: 22.4081 (variance of logit for case-control studies).
# Matching the GWAS meta-analysis results to the genotype data ...
# Calculating allele frequencies ...
# 182 SNP(s) have large difference of allele frequency between the GWAS summary data and the reference sample. These SNPs have been saved in [../../cojo/chr19/chr19.freq.badsnps].
# 807 SNPs are matched to the genotype data.
# Calculating the variance of SNP genotypes ...
#
# Performing stepwise model selection on 807 SNPs to select association signals ... (p cutoff = 5e-08; collinearity cutoff = 0.9)
# (Assuming complete linkage equilibrium between SNPs which are more than 10Mb away from each other)
# 5 associated SNPs have been selected.
# 10 associated SNPs have been selected.
# 15 associated SNPs have been selected.
# Finally, 19 associated SNPs are selected.
# Performing joint analysis on all the 19 selected signals ...
# Saving the 19 independent signals to [../../cojo/chr19/chr19.jma.cojo] ...
# Saving the LD structure of 19 independent signals to [../../cojo/chr19/chr19.ldr.cojo] ...
# Saving the conditional analysis results of 788 remaining SNPs to [../../cojo/chr19/chr19.cma.cojo] ...
# (0 SNPs eliminated by backward selection and 0 SNPs filtered by collinearity test are not included in the output)
#
# Analysis finished at 06:01:46 PST on Mon Feb 24 2025
# Overall computational time: 0.47 sec.

# %% [markdown]
# chr20

# %% [markdown]
# icog-bioai@dl:/mnt/hdd_2/rediet/hypothesis-generation-demo/data/susie/gcta/gcta-1.94.3-linux-kernel-3-x86_64$ gcta64 --bfile ../../ALL_chr/plink_b_files/chr20_eur_filtered --chr 20  --cojo-file ../../reformated_data_for_cojo/cojo_extracted_file.csv  --cojo-slct --out ../../cojo/chr20/chr20
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.94.1 Linux
# * Built at Dec 16 2024 16:35:13, by GCC 8.3
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 06:02:48 PST on Mon Feb 24 2025.
# Hostname: dl
#
# Accepted options:
# --bfile ../../ALL_chr/plink_b_files/chr20_eur_filtered
# --chr 20
# --cojo-file ../../reformated_data_for_cojo/cojo_extracted_file.csv
# --cojo-slct
# --out ../../cojo/chr20/chr20
#
#
# Reading PLINK FAM file from [../../ALL_chr/plink_b_files/chr20_eur_filtered.fam].
# 2504 individuals to be included from [../../ALL_chr/plink_b_files/chr20_eur_filtered.fam].
# Reading PLINK BIM file from [../../ALL_chr/plink_b_files/chr20_eur_filtered.bim].
# 676 SNPs to be included from [../../ALL_chr/plink_b_files/chr20_eur_filtered.bim].
# 676 SNPs on chromosome 20 are included in the analysis.
# Reading PLINK BED file from [../../ALL_chr/plink_b_files/chr20_eur_filtered.bed] in SNP-major format ...
# Genotype data for 2504 individuals and 676 SNPs to be included from [../../ALL_chr/plink_b_files/chr20_eur_filtered.bed].
#
# Reading GWAS summary-level statistics from [../../reformated_data_for_cojo/cojo_extracted_file.csv] ...
# GWAS summary statistics of 49937 SNPs read from [../../reformated_data_for_cojo/cojo_extracted_file.csv].
# Phenotypic variance estimated from summary statistics of all 49937 SNPs: 22.4081 (variance of logit for case-control studies).
# Matching the GWAS meta-analysis results to the genotype data ...
# Calculating allele frequencies ...
# 174 SNP(s) have large difference of allele frequency between the GWAS summary data and the reference sample. These SNPs have been saved in [../../cojo/chr20/chr20.freq.badsnps].
# 502 SNPs are matched to the genotype data.
# Calculating the variance of SNP genotypes ...
#
# Performing stepwise model selection on 502 SNPs to select association signals ... (p cutoff = 5e-08; collinearity cutoff = 0.9)
# (Assuming complete linkage equilibrium between SNPs which are more than 10Mb away from each other)
# 5 associated SNPs have been selected.
# Finally, 8 associated SNPs are selected.
# Performing joint analysis on all the 8 selected signals ...
# Saving the 8 independent signals to [../../cojo/chr20/chr20.jma.cojo] ...
# Saving the LD structure of 8 independent signals to [../../cojo/chr20/chr20.ldr.cojo] ...
# Saving the conditional analysis results of 494 remaining SNPs to [../../cojo/chr20/chr20.cma.cojo] ...
# (0 SNPs eliminated by backward selection and 0 SNPs filtered by collinearity test are not included in the output)
#
# Analysis finished at 06:02:48 PST on Mon Feb 24 2025
# Overall computational time: 0.26 sec.

# %% [markdown]
# chr21

# %% [markdown]
# icog-bioai@dl:/mnt/hdd_2/rediet/hypothesis-generation-demo/data/susie/gcta/gcta-1.94.3-linux-kernel-3-x86_64$ gcta64 --bfile ../../ALL_chr/plink_b_files/chr21_eur_filtered --chr 21  --cojo-file ../../reformated_data_for_cojo/cojo_extracted_file.csv  --cojo-slct --out ../../cojo/chr21/chr21
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.94.1 Linux
# * Built at Dec 16 2024 16:35:13, by GCC 8.3
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 06:03:58 PST on Mon Feb 24 2025.
# Hostname: dl
#
# Accepted options:
# --bfile ../../ALL_chr/plink_b_files/chr21_eur_filtered
# --chr 21
# --cojo-file ../../reformated_data_for_cojo/cojo_extracted_file.csv
# --cojo-slct
# --out ../../cojo/chr21/chr21
#
#
# Reading PLINK FAM file from [../../ALL_chr/plink_b_files/chr21_eur_filtered.fam].
# 2504 individuals to be included from [../../ALL_chr/plink_b_files/chr21_eur_filtered.fam].
# Reading PLINK BIM file from [../../ALL_chr/plink_b_files/chr21_eur_filtered.bim].
# 86 SNPs to be included from [../../ALL_chr/plink_b_files/chr21_eur_filtered.bim].
# 86 SNPs on chromosome 21 are included in the analysis.
# Reading PLINK BED file from [../../ALL_chr/plink_b_files/chr21_eur_filtered.bed] in SNP-major format ...
# Genotype data for 2504 individuals and 86 SNPs to be included from [../../ALL_chr/plink_b_files/chr21_eur_filtered.bed].
#
# Reading GWAS summary-level statistics from [../../reformated_data_for_cojo/cojo_extracted_file.csv] ...
# GWAS summary statistics of 49937 SNPs read from [../../reformated_data_for_cojo/cojo_extracted_file.csv].
# Phenotypic variance estimated from summary statistics of all 49937 SNPs: 22.4081 (variance of logit for case-control studies).
# Matching the GWAS meta-analysis results to the genotype data ...
# Calculating allele frequencies ...
# 16 SNP(s) have large difference of allele frequency between the GWAS summary data and the reference sample. These SNPs have been saved in [../../cojo/chr21/chr21.freq.badsnps].
# 70 SNPs are matched to the genotype data.
# Calculating the variance of SNP genotypes ...
#
# Performing stepwise model selection on 70 SNPs to select association signals ... (p cutoff = 5e-08; collinearity cutoff = 0.9)
# (Assuming complete linkage equilibrium between SNPs which are more than 10Mb away from each other)
# 5 associated SNPs have been selected.
# Finally, 5 associated SNPs are selected.
# Performing joint analysis on all the 5 selected signals ...
# Saving the 5 independent signals to [../../cojo/chr21/chr21.jma.cojo] ...
# Saving the LD structure of 5 independent signals to [../../cojo/chr21/chr21.ldr.cojo] ...
# Saving the conditional analysis results of 65 remaining SNPs to [../../cojo/chr21/chr21.cma.cojo] ...
# (0 SNPs eliminated by backward selection and 0 SNPs filtered by collinearity test are not included in the output)
#
# Analysis finished at 06:03:58 PST on Mon Feb 24 2025
# Overall computational time: 0.11 sec.

# %% [markdown]
# chr 22

# %% [markdown]
# icog-bioai@dl:/mnt/hdd_2/rediet/hypothesis-generation-demo/data/susie/gcta/gcta-1.94.3-linux-kernel-3-x86_64$ gcta64 --bfile ../../ALL_chr/plink_b_files/chr22_eur_filtered --chr 22  --cojo-file ../../reformated_data_for_cojo/cojo_extracted_file.csv  --cojo-slct --out ../../cojo/chr22/chr22
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.94.1 Linux
# * Built at Dec 16 2024 16:35:13, by GCC 8.3
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 06:04:51 PST on Mon Feb 24 2025.
# Hostname: dl
#
# Accepted options:
# --bfile ../../ALL_chr/plink_b_files/chr22_eur_filtered
# --chr 22
# --cojo-file ../../reformated_data_for_cojo/cojo_extracted_file.csv
# --cojo-slct
# --out ../../cojo/chr22/chr22
#
#
# Reading PLINK FAM file from [../../ALL_chr/plink_b_files/chr22_eur_filtered.fam].
# 2504 individuals to be included from [../../ALL_chr/plink_b_files/chr22_eur_filtered.fam].
# Reading PLINK BIM file from [../../ALL_chr/plink_b_files/chr22_eur_filtered.bim].
# 235 SNPs to be included from [../../ALL_chr/plink_b_files/chr22_eur_filtered.bim].
# 235 SNPs on chromosome 22 are included in the analysis.
# Reading PLINK BED file from [../../ALL_chr/plink_b_files/chr22_eur_filtered.bed] in SNP-major format ...
# Genotype data for 2504 individuals and 235 SNPs to be included from [../../ALL_chr/plink_b_files/chr22_eur_filtered.bed].
#
# Reading GWAS summary-level statistics from [../../reformated_data_for_cojo/cojo_extracted_file.csv] ...
# GWAS summary statistics of 49937 SNPs read from [../../reformated_data_for_cojo/cojo_extracted_file.csv].
# Phenotypic variance estimated from summary statistics of all 49937 SNPs: 22.4081 (variance of logit for case-control studies).
# Matching the GWAS meta-analysis results to the genotype data ...
# Calculating allele frequencies ...
# 94 SNP(s) have large difference of allele frequency between the GWAS summary data and the reference sample. These SNPs have been saved in [../../cojo/chr22/chr22.freq.badsnps].
# 141 SNPs are matched to the genotype data.
# Calculating the variance of SNP genotypes ...
#
# Performing stepwise model selection on 141 SNPs to select association signals ... (p cutoff = 5e-08; collinearity cutoff = 0.9)
# (Assuming complete linkage equilibrium between SNPs which are more than 10Mb away from each other)
# Finally, 2 associated SNPs are selected.
# Performing joint analysis on all the 2 selected signals ...
# Saving the 2 independent signals to [../../cojo/chr22/chr22.jma.cojo] ...
# Saving the LD structure of 2 independent signals to [../../cojo/chr22/chr22.ldr.cojo] ...
# Saving the conditional analysis results of 139 remaining SNPs to [../../cojo/chr22/chr22.cma.cojo] ...
# (0 SNPs eliminated by backward selection and 0 SNPs filtered by collinearity test are not included in the output)
#
# Analysis finished at 06:04:51 PST on Mon Feb 24 2025
# Overall computational time: 0.18 sec.
